# %% [markdown]
# # PCA

# %%
# Transposing and preparing data frames by excluding the last column for each sample type
df2 = br_df.T.iloc[:,:-1]
df3 = fa_df.T.iloc[:,:-1]
df4 = ur_df.T.iloc[:,:-1]

# Applying PCA using sklearn with 10 principal components
pca = PCA(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Transposing and preparing data frames by excluding the last column for each sample type
# ----> 2 df2 = br_df.T.iloc[:,:-1]
#       3 df3 = fa_df.T.iloc[:,:-1]
#       4 df4 = ur_df.T.iloc[:,:-1]
#
# NameError: name 'br_df' is not defined

# %% [markdown]
# ### BLOOD

# %%
# Fitting the PCA model to the data
pca.fit(df1)

# Printing the proportion of variance captured by each principal component
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# Plotting the proportion of variance explained by each principal component
plt.plot(range(1,11), pca.explained_variance_ratio_)
plt.xlabel('Principal component')
plt.ylabel('Explained variance')
plt.show()

# Defining a list of sample names
sample_names = df1.index
# Generating a score matrix by transforming the data using the fitted PCA model
df1_scores = pd.DataFrame(pca.transform((df1)), index=sample_names).T

# Creating a dictionary that maps each sample to its disease state
state = dict(zip(bl_df.columns, bl_df.loc["Sample_Type"]))
# Assigning colours to each sample based on its disease state
colour_key     = {'0': 'green', '1': 'red'}
# generating a list of sample colours using list comprehension
sample_colours = [colour_key[state[i]] for i in sample_names]

# Plotting a scatter plot of samples, where their position is determined by the first two principal component scores
plt.scatter(df1_scores.iloc[0], df1_scores.iloc[1], c=sample_colours)
# show the variance captured by each PC in the axis labels
plt.xlabel('PC1 ('+str(round(pca.explained_variance_ratio_[0]*100))+'%)')
plt.ylabel('PC2 ('+str(round(pca.explained_variance_ratio_[1]*100))+'%)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Fitting the PCA model to the data
# ----> 2 pca.fit(df1)
#       4 # Printing the proportion of variance captured by each principal component
#       5 print('Proportion of variance captured by each PC:')
#
# NameError: name 'pca' is not defined

# %% [markdown]
# # BREATH

# %%
# loding the data into a pca
pca.fit(df2)

# printing the result of pca
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# plotting proportion of variance explained by each PC
plt.plot(range(1,11), pca.explained_variance_ratio_)
plt.xlabel('Principal component')
plt.ylabel('Explained variance')
plt.show()

# defining a list of sample names
sample_names = df2.index
# generating a score matrix
df2_scores = pd.DataFrame(pca.transform((df2)), index=sample_names).T

# generating a dictionary with a disease state of each sample
state = dict(zip(br_df.columns, br_df.loc["Sample_Type"]))
# assigning colours to each samples 
colour_key     = {'0': 'green', '1': 'red'}
# generating a list of sample colours using list comprehension
sample_colours = [colour_key[state[i]] for i in sample_names]

# plotting samples in a scatter plot, where the position of each sample is determined by the first two PC scores
plt.scatter(df2_scores.iloc[0], df2_scores.iloc[1], c=sample_colours)
# show the variance captured by each PC in the axis labels
plt.xlabel('PC1 ('+str(round(pca.explained_variance_ratio_[0]*100))+'%)')
plt.ylabel('PC2 ('+str(round(pca.explained_variance_ratio_[1]*100))+'%)')
plt.show()
# Out:
# Proportion of variance captured by each PC:
# [8.37475518e-01 5.87719415e-02 4.84913119e-02 3.14473645e-02
#  1.80314127e-02 3.64490876e-03 9.72248051e-04 4.11691148e-04
#  2.43124600e-04 1.72131256e-04]

# %% [markdown]
# # FAECES

# %%
# loding the data into a pca
pca.fit(df3)

# printing the result of pca
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# plotting proportion of variance explained by each PC
plt.plot(range(1,11), pca.explained_variance_ratio_)
plt.xlabel('Principal component')
plt.ylabel('Explained variance')
plt.show()

# defining a list of sample names
sample_names = df3.index
# generating a score matrix
df3_scores = pd.DataFrame(pca.transform((df3)), index=sample_names).T

# generating a dictionary with a disease state of each sample
state = dict(zip(fa_df.columns, fa_df.loc["Sample_Type"]))
# assigning colours to each samples 
colour_key     = {'0': 'green', '1': 'red'}
# generating a list of sample colours using list comprehension
sample_colours = [colour_key[state[i]] for i in sample_names]

# plotting samples in a scatter plot, where the position of each sample is determined by the first two PC scores
plt.scatter(df3_scores.iloc[0], df3_scores.iloc[1], c=sample_colours)
# show the variance captured by each PC in the axis labels
plt.xlabel('PC1 ('+str(round(pca.explained_variance_ratio_[0]*100))+'%)')
plt.ylabel('PC2 ('+str(round(pca.explained_variance_ratio_[1]*100))+'%)')
plt.show()
# Out:
# Proportion of variance captured by each PC:
# [0.59364627 0.16898508 0.10527916 0.03932648 0.03243181 0.01618965
#  0.01110134 0.00826643 0.00583172 0.00465959]

# %% [markdown]
#  ### MAYBE HERE WE COULD POTENTIALLY DRAW A LINE BETWEEN CTR AND CD, BUT NOT REALLY EVIDENT

# %%
# Loading the data into PCA
pca.fit(df3)

# Printing the proportion of variance captured by each PC
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# Plotting the proportion of variance explained by each PC
plt.plot(range(1, 11), pca.explained_variance_ratio_, marker='o', linestyle='--', color='b')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance')
plt.title('Variance Explained by Each Principal Component')
plt.grid()
plt.show()

# Generating a score matrix
sample_names = df3.index
df3_scores = pd.DataFrame(pca.transform(df3), index=sample_names).T

# Generating a dictionary with a disease state for each sample
state = dict(zip(fa_df.columns, fa_df.loc["Sample_Type"]))

# Assigning colors to each sample based on disease state
colour_key = {'0': 'green', '1': 'red'}
sample_colours = [colour_key[state[i]] for i in sample_names]

# Plotting samples in a scatter plot for PC1 vs PC2
plt.figure(figsize=(8, 6))
plt.scatter(df3_scores.iloc[0], df3_scores.iloc[1], c=sample_colours, alpha=0.7, edgecolors='k')
plt.xlabel('PC1 (' + str(round(pca.explained_variance_ratio_[0] * 100, 2)) + '%)')
plt.ylabel('PC2 (' + str(round(pca.explained_variance_ratio_[1] * 100, 2)) + '%)')
plt.title('PCA: PC1 vs PC2')
plt.grid()
plt.show()

# Plotting samples in a scatter plot for PC1 vs PC3
plt.figure(figsize=(8, 6))
plt.scatter(df3_scores.iloc[0], df3_scores.iloc[2], c=sample_colours, alpha=0.7, edgecolors='k')
plt.xlabel('PC1 (' + str(round(pca.explained_variance_ratio_[0] * 100, 2)) + '%)')
plt.ylabel('PC3 (' + str(round(pca.explained_variance_ratio_[2] * 100, 2)) + '%)')
plt.title('PCA: PC1 vs PC3')
plt.grid()
plt.show()

# Plotting samples in a scatter plot for PC2 vs PC3
plt.figure(figsize=(8, 6))
plt.scatter(df3_scores.iloc[1], df3_scores.iloc[2], c=sample_colours, alpha=0.7, edgecolors='k')
plt.xlabel('PC2 (' + str(round(pca.explained_variance_ratio_[1] * 100, 2)) + '%)')
plt.ylabel('PC3 (' + str(round(pca.explained_variance_ratio_[2] * 100, 2)) + '%)')
plt.title('PCA: PC2 vs PC3')
plt.grid()
plt.show()
# Out:
# Proportion of variance captured by each PC:
# [0.59364627 0.16898508 0.10527916 0.03932648 0.03243181 0.01618965
#  0.01110134 0.00826643 0.00583172 0.00465959]

# %%
from mpl_toolkits.mplot3d import Axes3D

# Performing PCA on df3
pca.fit(df3)

# Printing the proportion of variance captured by each PC
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# Generating a score matrix for df3
sample_names = df3.index
df3_scores = pd.DataFrame(pca.transform(df3), index=sample_names).T

# Generating a dictionary with a disease state for each sample
state = dict(zip(fa_df.columns, fa_df.loc["Sample_Type"]))

# Assigning colors to each sample based on disease state
colour_key = {'0': 'green', '1': 'red'}
sample_colours = [colour_key[state[i]] for i in sample_names]

# Creating a 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting points in 3D space
sc = ax.scatter(
    df3_scores.iloc[0],  # PC1
    df3_scores.iloc[1],  # PC2
    df3_scores.iloc[2],  # PC3
    c=sample_colours,
    alpha=0.8,
    edgecolors='k'
)

# Adding axis labels
ax.set_xlabel('PC1 (' + str(round(pca.explained_variance_ratio_[0] * 100, 2)) + '%)')
ax.set_ylabel('PC2 (' + str(round(pca.explained_variance_ratio_[1] * 100, 2)) + '%)')
ax.set_zlabel('PC3 (' + str(round(pca.explained_variance_ratio_[2] * 100, 2)) + '%)')

# Adding a title
ax.set_title('3D PCA: PC1, PC2, and PC3')

# Displaying the plot
plt.show()
# Out:
# Proportion of variance captured by each PC:
# [0.59364627 0.16898508 0.10527916 0.03932648 0.03243181 0.01618965
#  0.01110134 0.00826643 0.00583172 0.00465959]

# %% [markdown]
# # URINE

# %%
# loding the data into a pca
pca.fit(df4)

# printing the result of pca
print('Proportion of variance captured by each PC:')
print(pca.explained_variance_ratio_)

# plotting proportion of variance explained by each PC
plt.plot(range(1,11), pca.explained_variance_ratio_)
plt.xlabel('Principal component')
plt.ylabel('Explained variance')
plt.show()

# defining a list of sample names
sample_names = df4.index
# generating a score matrix
df4_scores = pd.DataFrame(pca.transform((df4)), index=sample_names).T

# generating a dictionary with a disease state of each sample
state = dict(zip(ur_df.columns, ur_df.loc["Sample_Type"]))
# assigning colours to each samples 
colour_key     = {'0': 'green', '1': 'red'}
# generating a list of sample colours using list comprehension
sample_colours = [colour_key[state[i]] for i in sample_names]

# plotting samples in a scatter plot, where the position of each sample is determined by the first two PC scores
plt.scatter(df4_scores.iloc[0], df4_scores.iloc[1], c=sample_colours)
# show the variance captured by each PC in the axis labels
plt.xlabel('PC1 ('+str(round(pca.explained_variance_ratio_[0]*100))+'%)')
plt.ylabel('PC2 ('+str(round(pca.explained_variance_ratio_[1]*100))+'%)')
plt.show()
# Out:
# Proportion of variance captured by each PC:
# [0.56580317 0.31354829 0.06321562 0.03423446 0.01108974 0.00416386
#  0.0017334  0.00157333 0.00113572 0.00106686]

# %% [markdown]
# ### HERE NOT TOO BAD EITHER, BUT THOSE TWO RED OUTLIERS...

# %% [markdown]
# # Scikit-learn to build machine learning models to assign disease states to samples based on their GC-MS chromatograms.

# %% [markdown]
# # SUPPORT VECTOR MACHINES

# %% [markdown]
# ### This section was initially disorganised, as the process of building and testing the best model involved a trial-and-error approach to ultimately determine the optimal strategy. In the final version presented below, the sections have been restructured to reflect the correct, intuitive workflow. However, this revised structure may not fully capture the exploratory phase of the process.

# %% [markdown]
# ## Initial Evaluation of Sample Types(blood, breath, faecal, urine) to identify which one provides the best results for distinguishing CD from CTRL.

# %% [markdown]
# # Blood

# %%
######################################################
## Data split into into features (X) and labels (y) ##
######################################################

y = bl_sample_type        # Disease state
X = bl_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 1000 iterations with random train-test splits
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the SVM classifier
    clf = svm.SVC()
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc":accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparsion
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.4494 ± 0.1367

# %% [markdown]
# # Breath

# %%
######################################################
## Data split into into features (X) and labels (y) ##
######################################################

y = br_sample_type        # Disease state
X = br_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 1000 iterations with random train-test splits
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the SVM classifier
    clf = svm.SVC()
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc":accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparsion
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.4187 ± 0.1062

# %% [markdown]
# # Faeces

# %%
######################################################
## Data split into into features (X) and labels (y) ##
######################################################

y = fa_sample_type        # Disease state
X = fa_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 1000 iterations with random train-test splits
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the SVM classifier
    clf = svm.SVC()
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc":accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparsion
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.6761 ± 0.1844

# %% [markdown]
# # Urine

# %%
######################################################
## Data split into into features (X) and labels (y) ##
######################################################

y = ur_sample_type        # Disease state
X = ur_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 1000 iterations with random train-test splits
for i in range(1000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the SVM classifier
    clf = svm.SVC()
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc":accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparsion
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.6121 ± 0.1540

# %% [markdown]
# # Selecting the Best Sample Type

# %% [markdown]
# ## SINCE THE BEST MEAN ACCURACY WAS RECORDED FOR THE FAECAL SAMPLE TYPE (Mean Accuracy: 0.6757 ± 0.1828), ONLY THIS SAMPLE TYPE WILL BE USED TO BUILD THE FINAL MODEL

# %% [markdown]
# Please note that some code refinements in this section were made with the help of ChatGPT to expedite the process, improve the organisation of the code, and enhance the formatting (of the print function) for better readability.
#
# OpenAI. (2024). ChatGPT (Dec 2024) https://openai.com/chatgpt

# %% [markdown]
# # Hyperparameter Tuning and Kernel Selection

# %%
# Definining the kernels I want to try
kernels = ['linear', 'poly', 'rbf', 'sigmoid']

# Dictionary to store best models for each kernel
best_models = {}

# Hyperparameter grid (C and gamma) to tune
param_grid = {
    'C': [0.01, 0.01, 0.1, 1, 10, 100],  # Various values of C
    'gamma': [0.00001, 0.0001, 0.001, 0.1, 0.1, 1]  # Various values of gamma
}

# Loop over the different kernels and perform GridSearchCV
for kernel in kernels:
    print(f"Testing kernel: {kernel}")
    
    # Initialise the SVM classifier with the current kernel
    clf = SVC(kernel=kernel)
    
    # Use GridSearchCV to find the best parameters for the current kernel
    # param_grid= specifies the hyperparameters to test param_grid is a dictionary where the keys are hyperparameter names, and the values are lists of values 
    # cv=5 5-fold cross-validation, which splits the data into 5 subsets (or "folds") 
    # The model is trained on 4 of these folds and tested on the remaining fold, repeating the process 5 times
    # verbose= controls the amount of information displayed during the execution of GridSearchCV
    # verbose=1 shows a basic progress of the search
    # n_jobs=-1 means using all available CPU cores for parallel processing
    
    grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, verbose=1, n_jobs=-1)
    grid_search.fit(X, y)
    
    # Store the best model for this kernel
    best_models[kernel] = grid_search.best_estimator_
    
    # Print the best parameters found by GridSearchCV
    print(f"Best parameters for {kernel} kernel: {grid_search.best_params_}")
    
    # Get the best model and fit it
    best_svm = grid_search.best_estimator_
    
    # Print the accuracy of the best model on the training data
    print(f"Best model accuracy for {kernel} kernel on training data: {best_svm.score(X, y)}")
    
    # Evaluate the performance of the best model using cross-validation
    cv_scores = cross_val_score(best_svm, X, y, cv=5)  # 5-fold cross-validation
    print(f"Cross-validation scores for {kernel} kernel: {cv_scores}")
    print(f"Average cross-validation score for {kernel} kernel: {cv_scores.mean()}")
    
    # Fitting the best svm hyperparameters and kernel with our test data
    y_pred_test = best_svm.predict(X_test)
    
    # Compute and display the confusion matrix
    cm = confusion_matrix(y_test, y_pred_test)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix for {kernel} Kernel")
    plt.show()
# Out:
# Testing kernel: linear
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for linear kernel: {'C': 0.01, 'gamma': 1e-05}
# Best model accuracy for linear kernel on training data: 1.0
# Cross-validation scores for linear kernel: [0.8  0.8  0.6  1.   0.75]
# Average cross-validation score for linear kernel: 0.79
# Testing kernel: poly
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for poly kernel: {'C': 0.01, 'gamma': 0.001}
# Best model accuracy for poly kernel on training data: 1.0
# Cross-validation scores for poly kernel: [0.8  1.   0.2  1.   0.75]
# Average cross-validation score for poly kernel: 0.75
# Testing kernel: rbf
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for rbf kernel: {'C': 1, 'gamma': 0.0001}
# Best model accuracy for rbf kernel on training data: 1.0
# Cross-validation scores for rbf kernel: [0.8  0.8  0.6  1.   0.75]
# Average cross-validation score for rbf kernel: 0.79
# Testing kernel: sigmoid
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for sigmoid kernel: {'C': 1, 'gamma': 0.0001}
# Best model accuracy for sigmoid kernel on training data: 0.8695652173913043
# Cross-validation scores for sigmoid kernel: [1.   0.8  0.8  1.   0.75]
# Average cross-validation score for sigmoid kernel: 0.8699999999999999

# %% [markdown]
# # Final Model Performance

# %%
# Defining the feature set (X) and disease state (y)
X = fa_df.T.iloc[:, :-1]  # Features with shape (23, 4349)
y = fa_sample_type  # disease state

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Fit and predict using SVM
clf = SVC(kernel='rbf', C=1, gamma=0.0001)
clf.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.0001)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8571428571428571

# %% [markdown]
# # CHECKING THE PERFORMANCE TO DIFFERENTIATE BETWEED CD AND OTHER SAMPLES (CD VS ALL)

# %%
fa_cdvsall = {}
loadmat("ai_and_data science/Day_4/gcms_data/faecal/BWG_FA_CDvALL.mat", mdict=fa_cdvsall, appendmat=False)
fa_cdvsall_df = gcparser(fa_cdvsall)
# Adding a new row indicating "CTRL" or "CD"
fa_cdvsall_df.loc["Sample_Type"] = fa_cdvsall_df.columns.map(lambda col: "1" if "_CD" in col else "0")
fa_cdvsall_type = fa_cdvsall_df.loc["Sample_Type"].tolist()
# Defining the feature set (X) and disease state (y)
X_test = fa_cdvsall_df.T.iloc[:, :-1]  # Features with shape (23, 4349)
y_test = fa_cdvsall_type  # disease state

# %%
# Defining the feature set (X) and disease state (y)
X = fa_df.T.iloc[:, :-1]  # Features with shape (23, 4349)
y = fa_sample_type  # disease state

# %%
# Split the data into training and testing sets for final evaluation,random_state=42 for reproduction of the results 


clf = SVC(kernel='rbf', C=1, gamma=0.001)
clf.fit(X, y)

accuracies = []  # List to store accuracy for each iteration
for i in range(100):
    clf = SVC(kernel='rbf', C=1, gamma=0.001)
    clf.fit(X, y)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    
# Convert accuracies to a DataFrame and plot the distribution
acc = pd.DataFrame({"acc": accuracies})
acc.hist()
plt.title('Distribution of Accuracy over 100 Iterations')
plt.xlabel('Accuracy')
plt.ylabel('Frequency')
plt.show()


# Calculating a mean and std for accuracies for comparsion
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
# Printing results
print(accuracies)
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# [0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111, 0.5111111111111111]
# Mean Accuracy: 0.5111 ± 0.0000

# %%
# Test set accuracy
test_accuracy = clf.score(X_test, y_test)
print(f"Test set accuracy: {test_accuracy}")

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Compute and display the confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix for RBF Kernel")
# Save and display the figure
plt.savefig("confusion_matrix_best_rbf.png", dpi=300)
plt.show()
# Out:
# Test set accuracy: 0.5111111111111111

# %% [markdown]
# # Permutation

# %% [markdown]
# # Permutation Test for Statistical Significance

# %%
# Define the classifier
clf = SVC(kernel='rbf', C=1, gamma=0.0001)

# Stratified K-Fold cross-validation setup with random_state for reproducibility
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# Real data permutation test
score_real, perm_scores_real, p_value_real = permutation_test_score(
    clf, X, y, scoring="accuracy", cv=cv, n_permutations=1000, random_state=0
)
print(f"Real Data - Permutation Test Score: {score_real}")
print(f"Real Data - P-value: {p_value_real}")

X_rand = np.random.permutation(X)  # Shuffle feature matrix

# Randomised data permutation test
score_rand, perm_scores_rand, p_value_rand = permutation_test_score(
    clf, X_rand, y, scoring="accuracy", cv=cv, n_permutations=1000, random_state=0
)
print(f"Randomized Data - Permutation Test Score: {score_rand}")
print(f"Randomized Data - P-value: {p_value_rand}")

# Plotting results
plt.hist(perm_scores_real, bins=30, alpha=0.7, label="Real Data Permuted Accuracies")
plt.axvline(score_real, color='red', linestyle='--', label=f"Real Data Accuracy ({score_real:.2f})")
plt.xlabel("Accuracy")
plt.ylabel("Frequency")
plt.title("Real Data Permutation Test Results")
plt.legend()
plt.show()
# Out:
# Real Data - Permutation Test Score: 0.79
# Real Data - P-value: 0.016983016983016984
# Randomized Data - Permutation Test Score: 0.31
# Randomized Data - P-value: 0.9440559440559441

# %% [markdown]
# # PERMUTATION FEATURE IMPORTANCE

# %%
feature_names = X_test.columns

# %%
print("Calculating permutation importance...")
try:
    # Reduce repeats for testing, increase once it works
    r = permutation_importance(best_svc, X_test, y_test, n_repeats=10, random_state=0)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Calculating permutation importance...

# %%
print("Permutation importance calculated. Displaying results:")

# Iterate through sorted importances and display results
for i in r.importances_mean.argsort()[::-1]:  # Sort indices by importance descending
    if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
        print(f"Retention Time: {feature_names[i]:<10.3f} "
              f"Mean Importance: {r.importances_mean[i]:.3f} "
              f"+/- {r.importances_std[i]:.3f}")
# Out:
# Permutation importance calculated. Displaying results:
# Retention Time: 13.869     Mean Importance: 0.171 +/- 0.086
# Retention Time: 22.811     Mean Importance: 0.171 +/- 0.086
# Retention Time: 13.882     Mean Importance: 0.171 +/- 0.086
# Retention Time: 13.876     Mean Importance: 0.171 +/- 0.086
# Retention Time: 22.824     Mean Importance: 0.171 +/- 0.086
# Retention Time: 22.817     Mean Importance: 0.171 +/- 0.086
# Retention Time: 22.804     Mean Importance: 0.157 +/- 0.077

# %% [markdown]
# # RANDOM FOREST

# %% [markdown]
# ## Initial Evaluation of Sample Types(blood, breath, faecal, urine) to identify which one provides the best results for distinguishing CD from CTRL.

# %% [markdown]
# # BLOOD

# %%
######################################################
## Data split into features (X) and labels (y) ##
######################################################

y = bl_sample_type        # Disease state
X = bl_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 100 iterations with random train-test splits
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the Random Forest classifier
    clf = RandomForestClassifier(n_estimators=100)  # Random Forest classifier
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc": accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparison
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.4490 ± 0.1330

# %% [markdown]
# # BREATH

# %%
######################################################
## Data split into features (X) and labels (y) ##
######################################################

y = br_sample_type        # Disease state
X = br_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 100 iterations with random train-test splits
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the Random Forest classifier
    clf = RandomForestClassifier(n_estimators=100)  # Random Forest classifier
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc": accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparison
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.6100 ± 0.1173

# %% [markdown]
# # FAECES

# %%
######################################################
## Data split into features (X) and labels (y) ##
######################################################

y = fa_sample_type        # Disease state
X = fa_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 100 iterations with random train-test splits
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the Random Forest classifier
    clf = RandomForestClassifier(n_estimators=100)  # Random Forest classifier
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc": accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparison
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.8371 ± 0.1278

# %% [markdown]
# # URINE

# %%
######################################################
## Data split into features (X) and labels (y) ##
######################################################

y = ur_sample_type        # Disease state
X = ur_df.T.iloc[:, :-1]  # Features with shape (23, 4349)

###################
## Bootstrapping ##
###################

accuracies = []  # List to store accuracy for each iteration

# Performing 100 iterations with random train-test splits
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # SPLIT 30/70
    # Initialise and train the Random Forest classifier
    clf = RandomForestClassifier(n_estimators=100)  # Random Forest classifier
    clf.fit(X_train, y_train)
    # Predict on the test set and calculate accuracy
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    # Append the accuracy to the list
    accuracies.append(accuracy)

# Making a dataframe for the accuracies from the bootstrapping
acc = pd.DataFrame({"acc": accuracies})

############
# Plotting #
############

acc.hist()

# Calculating a mean and std for accuracies for comparison
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

# Printing results
print(f'Mean Accuracy: {mean_accuracy:.4f} ± {std_accuracy:.4f}')
# Out:
# Mean Accuracy: 0.6029 ± 0.1779

# %% [markdown]
# # Hyperparameter Tuning and Kernel Selection

# %%
# Defining a simple set of hyperparameters for Random Forest
param_grid = {
    'n_estimators': [100, 200],  # Number of trees
    'max_depth': [None, 10, 20],  # Depth of trees (None means nodes are expanded until they contain less than min_samples_split samples)
    'min_samples_split': [2, 5],  # Minimum number of samples required to split an internal node
    'max_features': ['sqrt', 'log2', None]  # Features to consider when looking for the best split
}

# Initialise the Random Forest model
rf = RandomForestClassifier(random_state=0)

# Initialise GridSearchCV to test the above hyperparameters
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, verbose=1, n_jobs=-1)

# Fit the model
grid_search.fit(X, y)

# Print the best parameters found
print(f"Best Parameters: {grid_search.best_params_}")

# Get the best model from GridSearchCV
best_rf = grid_search.best_estimator_

# Print the accuracy of the best model on the training data
print(f"Best model accuracy on training data: {best_rf.score(X, y)}")

# Cross-validation scores
cv_scores = cross_val_score(best_rf, X, y, cv=5)
print(f"Cross-validation scores: {cv_scores}")
print(f"Average cross-validation score: {cv_scores.mean()}")

# Fit the best model to the test data (replace X_test with your actual test data)
y_pred_test = best_rf.predict(X_test)

# Compute and display the confusion matrix
cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f"Confusion Matrix for Best RF Model")
plt.show()
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}
# Best model accuracy on training data: 1.0
# Cross-validation scores: [1.  0.6 0.8 1.  1. ]
# Average cross-validation score: 0.8800000000000001

# %% [markdown]
# # Permutation

# %%
# Define the classifier
clf_rf = RandomForestClassifier(max_features='log2', n_estimators=200, random_state=0)

# Stratified K-Fold cross-validation setup with random_state for reproducibility
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# Real data permutation test
score_real, perm_scores_real, p_value_real = permutation_test_score(
    clf_rf, X, y, scoring="accuracy", cv=cv, n_permutations=1000, random_state=0
)
print(f"Real Data - Permutation Test Score: {score_real}")
print(f"Real Data - P-value: {p_value_real}")

X_rand = np.random.permutation(X)  # Shuffle feature matrix

# Randomised data permutation test
score_rand, perm_scores_rand, p_value_rand = permutation_test_score(
    clf_rf, X_rand, y, scoring="accuracy", cv=cv, n_permutations=1000, random_state=0
)
print(f"Randomized Data - Permutation Test Score: {score_rand}")
print(f"Randomized Data - P-value: {p_value_rand}")

# Plotting results
plt.hist(perm_scores_real, bins=30, alpha=0.7, label="Real Data Permuted Accuracies")
plt.axvline(score_real, color='red', linestyle='--', label=f"Real Data Accuracy ({score_real:.2f})")
plt.xlabel("Accuracy")
plt.ylabel("Frequency")
plt.title("Real Data Permutation Test Results")
plt.legend()
plt.show()
# Out:
# Real Data - Permutation Test Score: 0.82
# Real Data - P-value: 0.008991008991008992
# Randomized Data - Permutation Test Score: 0.53
# Randomized Data - P-value: 0.41858141858141856
